# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os

# %%
import math
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Funções Auxiliares

# %%
def normalize(df):
    mindf = df.min()
    maxdf = df.max()
    return (df-mindf)/(maxdf-mindf)

# %%
def denormalize(norm, _min, _max):
    return [(n * (_max-_min)) + _min for n in norm]

# %%
def split_data(df, interval):
    sample_df = df.loc[interval]

    week = (sample_df.index.day - 1) // 7 + 1

    # PARA OS TESTES:
    # 2 SEMANAS PARA TREINAMENTO
    train_df = sample_df.loc[week <= 2]

    # 1 SEMANA PARA VALIDACAO
    validation_df = sample_df.loc[week == 3]

    # 1 SEMANA PARA TESTES
    test_df = sample_df.loc[week > 3]
    
    return (train_df, validation_df, test_df)

# %%
def calculate_rmse(test, forecast, order, step):
    rmse = math.sqrt(mean_squared_error(test.iloc[(order):], forecast[:-step]))
    print("RMSE : "+str(rmse))
    return rmse

# %%
def reconstruct_ssa_series(clean, residual):
    return [r + c for r, c in zip(residual,clean)]

# %%
def save_obj(obj, name ):
    with open('results/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('results/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
def difference(raw_df, interval=1):
    df_diff = pd.DataFrame(columns=raw_df.columns, index=raw_df.index[1:])
    
    for col in raw_df.columns:
        raw_array = raw_df[col]
        diff = []
        for i in range(interval, len(raw_array)):
            value = raw_array[i] - raw_array[i - interval]
            diff.append(value)
        
        df_diff[col] = diff
    return df_diff

# %%
def inverse_difference(raw_series, diff_series):
    inverted = []
    for i in range(len(diff_series)):
        interval = len(raw_series)-i
        value = diff_series[i] + raw_series[-interval]
        inverted.append(value)
        
    return inverted

# %% [markdown]
# # Load Dataset
# Split the data into train, validation and test subsets

# %%
#Set target and input variables 
target_station = 'DHHL_3'

#All neighbor stations with residual correlation greater than .90
neighbor_stations_90 = ['DHHL_3',  'DHHL_4','DHHL_5','DHHL_10','DHHL_11','DHHL_9','DHHL_2', 'DHHL_6','DHHL_7','DHHL_8']

# %%
df = pd.read_pickle(os.path.join(os.getcwd(), "../data/oahu/df_oahu.pkl"))

# %%
## Remove columns with many corrupted or missing values
df.drop(columns=['AP_1', 'AP_7'], inplace=True)

# %%
#Normalize Data

# Save Min-Max for Denorm
min_raw = df[target_station].min()

max_raw = df[target_station].max()

# Perform Normalization
norm_df = normalize(df)

# %%
# Split data
interval = ((df.index >= '2010-06') & (df.index < '2010-07'))
#interval = ((df.index >= '2010-11') & (df.index <= '2010-12'))

(train_df, validation_df, test_df) = split_data(df, interval)
(norm_train_df, norm_validation_df, norm_test_df) = split_data(norm_df, interval)

# %% [markdown]
# ## Forecasting with Raw Time Series
#
# For each dataset, all the time series were normalized

# %% [markdown]
# ## FuzzyImageCNN

# %%
from pyFTS.partitioners import Grid, Entropy, Util as pUtil

from fts2image import FuzzyImageCNN
# Out:
# Using TensorFlow backend.

# %%
def fuzzy_cnn_forecast(train_df, test_df):

    
    _conv_layers = 2
    _dense_layer_neurons = 1024
    _dense_layers = 3
    _epochs = 30
    _filters = 8
    _kernel_size = 2
    _npartitions = 50
    _order = 8
    _pooling_size = 2
    

    fuzzy_sets = Grid.GridPartitioner(data=train_df.values, npart=_npartitions).sets
    model = FuzzyImageCNN.FuzzyImageCNN(fuzzy_sets, nlags=_order, steps=1,
                                       conv_layers=_conv_layers, dense_layers = _dense_layers, 
                                        dense_layer_neurons=_dense_layer_neurons, filters=_filters,
                                       kernel_size=_kernel_size, pooling_size=_pooling_size)
    model.fit(train_df, epochs=_epochs, batch_size=64)

    forecast = model.predict(test_df)    

    return forecast

# %%
steps = 1

forecast = fuzzy_cnn_forecast(norm_train_df[target_station], norm_test_df[target_station])
forecast = denormalize(forecast, min_raw, max_raw)
# Out:
# Epoch 1/1
# 846/846 [==============================] - 1s 1ms/step - loss: 0.0331

# %%
_order = 8

# %%
forecast.append(0) ## para manter o mesmo tamanho dos demais
rmse = calculate_rmse(test_df[target_station], forecast, _order, steps)
# Out:
# RMSE : 148.81590526087942

# %% [markdown]
# ### Parameter optimization

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt import space_eval

# %%
space = {'npartitions': hp.choice('npartitions', [50, 100, 150, 200]),
            'order': hp.choice('order', list(np.arange(4,10))),
             'epochs': hp.choice('epochs', [30, 50, 100])}

# %%
def cnn_objective(params):
    print(params)
    forecast = fuzzy_cnn_forecast(norm_train_df[target_station], norm_test_df[target_station], params['order'], 1, params['npartitions'], params['epochs'])
    forecast = denormalize(forecast, min_raw, max_raw)
    forecast.append(0) ## para manter o mesmo tamanho dos demais
    rmse = calculate_rmse(test_df[target_station], forecast, params['order'], 1) 
    return {'loss': rmse, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(cnn_objective, space, algo=tpe.suggest, max_evals =200, trials=trials)
# Out:
# {'epochs': 50, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 2s 2ms/step - loss: 0.0626
# RMSE : 223.6843606526732
# {'epochs': 100, 'npartitions': 100, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 2s 2ms/step - loss: 0.0867
# RMSE : 191.90993566596345
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 1s 2ms/step - loss: 0.0928
# RMSE : 266.834131922861
# {'epochs': 30, 'npartitions': 150, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 2s 2ms/step - loss: 0.0373
# RMSE : 169.86460110128886
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 2s 2ms/step - loss: 0.0388
# RMSE : 185.52169762433465
# {'epochs': 50, 'npartitions': 200, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 3s 3ms/step - loss: 0.0359
# RMSE : 179.8822960193808
# {'epochs': 100, 'npartitions': 150, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 2s 2ms/step - loss: 0.0616
# RMSE : 232.08980107692076
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 2s 2ms/step - loss: 0.0321
# RMSE : 168.18023539624957
# {'epochs': 30, 'npartitions': 150, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 2s 3ms/step - loss: 0.0326
# RMSE : 176.01527818947008
# {'epochs': 100, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 2ms/step - loss: 0.0825
# RMSE : 178.13691315914545
# {'epochs': 30, 'npartitions': 150, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 2s 3ms/step - loss: 0.0409
# RMSE : 184.91178446210174
# {'epochs': 50, 'npartitions': 200, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 3s 3ms/step - loss: 0.0433
# RMSE : 193.26055420217656
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 2s 2ms/step - loss: 0.0421
# RMSE : 171.16854769109352
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 2ms/step - loss: 0.0459
# RMSE : 159.53819506935852
# {'epochs': 50, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 2ms/step - loss: 0.0518
# RMSE : 180.77877458367908
# {'epochs': 50, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 2s 2ms/step - loss: 0.0525
# RMSE : 197.86248493110114
# {'epochs': 50, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 2ms/step - loss: 0.0532
# RMSE : 177.06066066418938
# {'epochs': 30, 'npartitions': 200, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 3s 3ms/step - loss: 0.0346
# RMSE : 187.57895086847608
# {'epochs': 100, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 2s 2ms/step - loss: 0.0669
# RMSE : 212.40821959136787
# {'epochs': 50, 'npartitions': 200, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 2s 3ms/step - loss: 0.0516
# RMSE : 191.4669750026033
# {'epochs': 30, 'npartitions': 100, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 2s 3ms/step - loss: 0.0380
# RMSE : 194.38114079990964
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 2ms/step - loss: 0.0373
# RMSE : 158.73890895140892
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 2ms/step - loss: 0.0349
# RMSE : 156.8264695060837
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0396
# RMSE : 159.22194703753485
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0334
# RMSE : 160.79497060695542
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0431
# RMSE : 161.03036277922345
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0329
# RMSE : 157.50506588857928
# {'epochs': 30, 'npartitions': 100, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 2s 3ms/step - loss: 0.0496
# RMSE : 191.37207116778495
# {'epochs': 30, 'npartitions': 100, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 2s 3ms/step - loss: 0.0324
# RMSE : 168.0393230360726
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0416
# RMSE : 158.05513439345643
# {'epochs': 100, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0836
# RMSE : 185.66757245611402
# {'epochs': 30, 'npartitions': 100, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 3s 3ms/step - loss: 0.0354
# RMSE : 172.69261540227723
# {'epochs': 100, 'npartitions': 100, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 2s 3ms/step - loss: 0.0724
# RMSE : 173.8569348075816
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 3ms/step - loss: 0.0412
# RMSE : 154.6806070990489
# {'epochs': 30, 'npartitions': 100, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 3s 3ms/step - loss: 0.0395
# RMSE : 188.98915617199683
# {'epochs': 100, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 2s 3ms/step - loss: 0.0963
# RMSE : 236.28004053711658
# {'epochs': 30, 'npartitions': 150, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 3s 3ms/step - loss: 0.0431
# RMSE : 171.99120735354788
# {'epochs': 30, 'npartitions': 100, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 3s 3ms/step - loss: 0.0375
# RMSE : 182.9408848879448
# {'epochs': 50, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 3s 3ms/step - loss: 0.0477
# RMSE : 190.2400264156303
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 3ms/step - loss: 0.0427
# RMSE : 156.86081848389952
# {'epochs': 100, 'npartitions': 100, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 3s 3ms/step - loss: 0.0763
# RMSE : 194.58121846152997
# {'epochs': 30, 'npartitions': 200, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 4s 4ms/step - loss: 0.0361
# RMSE : 183.8824451356498
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 3s 3ms/step - loss: 0.0398
# RMSE : 184.96719346332512
# {'epochs': 50, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.0412
# RMSE : 189.02687704278733
# {'epochs': 100, 'npartitions': 100, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 3s 4ms/step - loss: 0.0611
# RMSE : 233.06607673097795
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 3ms/step - loss: 0.0426
# RMSE : 156.45818050906945
# {'epochs': 30, 'npartitions': 200, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 3s 4ms/step - loss: 0.0471
# RMSE : 170.18736800490365
# {'epochs': 50, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 3s 3ms/step - loss: 0.0533
# RMSE : 201.43917986879603
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.0421
# RMSE : 157.92975964498834
# {'epochs': 100, 'npartitions': 100, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 3s 4ms/step - loss: 0.0868
# RMSE : 198.40344097142795
# {'epochs': 50, 'npartitions': 200, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 4s 5ms/step - loss: 0.0504
# RMSE : 221.34164917826945
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 3s 4ms/step - loss: 0.0396
# RMSE : 193.2125694242931
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.0379
# RMSE : 168.78462380857343
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.0376
# RMSE : 156.98193361806923
# {'epochs': 50, 'npartitions': 100, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 3s 4ms/step - loss: 0.0507
# RMSE : 194.75124209241002
# {'epochs': 30, 'npartitions': 200, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 4s 5ms/step - loss: 0.0362
# RMSE : 190.34603781325018
# {'epochs': 100, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.0880
# RMSE : 242.9118443953259
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 3s 4ms/step - loss: 0.0333
# RMSE : 195.01300410928943
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.0452
# RMSE : 155.60150192606594
# {'epochs': 50, 'npartitions': 150, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 4s 4ms/step - loss: 0.0518
# RMSE : 184.818281027491
# {'epochs': 30, 'npartitions': 100, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 4s 4ms/step - loss: 0.0332
# RMSE : 179.19127019359217
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0369
# RMSE : 156.44227151416692
# {'epochs': 100, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 3s 4ms/step - loss: 0.1031
# RMSE : 303.83617511828714
# {'epochs': 30, 'npartitions': 100, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 4s 5ms/step - loss: 0.0388
# RMSE : 177.20560338503668
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0333
# RMSE : 154.89198074500024
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0320
# RMSE : 151.55529567538952
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0325
# RMSE : 153.3473648641881
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0328
# RMSE : 159.41585961658234
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0403
# RMSE : 162.483076964928
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0361
# RMSE : 169.51353837547416
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0273
# RMSE : 155.17622154876616
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 4ms/step - loss: 0.0357
# RMSE : 158.26451097572385
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 4s 5ms/step - loss: 0.0352
# RMSE : 178.98998986749712
# {'epochs': 30, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 4s 4ms/step - loss: 0.0410
# RMSE : 164.74217167431095
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 4s 5ms/step - loss: 0.0378
# RMSE : 185.59057912438638
# {'epochs': 50, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 5ms/step - loss: 0.0521
# RMSE : 182.63257988804014
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 4s 5ms/step - loss: 0.0345
# RMSE : 186.62640799709706
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 5ms/step - loss: 0.0935
# RMSE : 235.86070447079462
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 4s 5ms/step - loss: 0.0395
# RMSE : 173.5437219022916
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 5ms/step - loss: 0.0354
# RMSE : 150.36844746510582
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 5ms/step - loss: 0.0366
# RMSE : 158.98499272542008
# {'epochs': 50, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 4s 5ms/step - loss: 0.0492
# RMSE : 196.36997802166758
# {'epochs': 30, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 4s 5ms/step - loss: 0.0412
# RMSE : 170.5173041861848
# {'epochs': 100, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 4s 5ms/step - loss: 0.0983
# RMSE : 295.18684271957324
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 5ms/step - loss: 0.0341
# RMSE : 153.37678156880546
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 4s 5ms/step - loss: 0.0348
# RMSE : 192.73183230572224
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 4s 5ms/step - loss: 0.0476
# RMSE : 169.5671073530218
# {'epochs': 50, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 4s 5ms/step - loss: 0.0691
# RMSE : 204.28344481562428
# {'epochs': 100, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 5ms/step - loss: 0.0668
# RMSE : 159.34690983542706
# {'epochs': 30, 'npartitions': 200, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 5s 6ms/step - loss: 0.0331
# RMSE : 188.55786109009148
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 5ms/step - loss: 0.0349
# RMSE : 150.73600614750853
# {'epochs': 30, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 5s 5ms/step - loss: 0.0394
# RMSE : 168.53178700044882
# {'epochs': 50, 'npartitions': 150, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 5s 6ms/step - loss: 0.0522
# RMSE : 198.26850471501115
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 5s 6ms/step - loss: 0.0397
# RMSE : 176.96201855202537
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 5ms/step - loss: 0.0693
# RMSE : 180.1360746995162
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0379
# RMSE : 164.39608347731598
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 5s 6ms/step - loss: 0.0373
# RMSE : 171.05185136425698
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0392
# RMSE : 156.1226758481734
# {'epochs': 50, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 5s 6ms/step - loss: 0.0472
# RMSE : 189.36035989926944
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0397
# RMSE : 156.58661388500568
# {'epochs': 100, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 5s 6ms/step - loss: 0.0666
# RMSE : 201.95632499287314
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 5s 6ms/step - loss: 0.0412
# RMSE : 187.04511941674173
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0468
# RMSE : 154.51977768347876
# {'epochs': 30, 'npartitions': 150, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 5s 6ms/step - loss: 0.0399
# RMSE : 180.22000327214815
# {'epochs': 50, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0482
# RMSE : 174.4115254202285
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 5s 6ms/step - loss: 0.0374
# RMSE : 170.5290296366991
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0732
# RMSE : 196.05754616326402
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0427
# RMSE : 167.1941935125414
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 5s 6ms/step - loss: 0.0282
# RMSE : 172.99699356997152
# {'epochs': 30, 'npartitions': 150, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 6s 7ms/step - loss: 0.0382
# RMSE : 166.90851102154576
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0413
# RMSE : 156.05562341169522
# {'epochs': 50, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 5s 6ms/step - loss: 0.0483
# RMSE : 205.16936201161246
# {'epochs': 100, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 5s 6ms/step - loss: 0.0611
# RMSE : 226.81783963239027
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 5s 6ms/step - loss: 0.0350
# RMSE : 159.29835482155818
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 6s 7ms/step - loss: 0.0481
# RMSE : 188.097891186337
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0319
# RMSE : 154.78122199219342
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 6ms/step - loss: 0.0319
# RMSE : 154.51986199912372
# {'epochs': 50, 'npartitions': 200, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 6s 8ms/step - loss: 0.0366
# RMSE : 180.16864250511256
# {'epochs': 30, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 6s 7ms/step - loss: 0.0355
# RMSE : 172.44492227557015
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0700
# RMSE : 202.66337253016127
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 6s 7ms/step - loss: 0.0445
# RMSE : 187.97888813788754
# {'epochs': 30, 'npartitions': 150, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 6s 7ms/step - loss: 0.0313
# RMSE : 167.1267194737215
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0337
# RMSE : 155.4398548405627
# {'epochs': 50, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0401
# RMSE : 177.58985529030687
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0407
# RMSE : 167.32538529627178
# {'epochs': 100, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 6s 7ms/step - loss: 0.0702
# RMSE : 204.41518799178235
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 6s 7ms/step - loss: 0.0332
# RMSE : 168.3031832500822
# {'epochs': 30, 'npartitions': 150, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 6s 7ms/step - loss: 0.0410
# RMSE : 164.15911042232267
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0332
# RMSE : 155.2711010217326
# {'epochs': 50, 'npartitions': 200, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 7s 8ms/step - loss: 0.0557
# RMSE : 200.43838563503732
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 6s 7ms/step - loss: 0.0458
# RMSE : 197.68943936827296
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0696
# RMSE : 180.7385425152458
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 6s 7ms/step - loss: 0.0409
# RMSE : 163.36377519269277
# {'epochs': 30, 'npartitions': 100, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 7s 8ms/step - loss: 0.0311
# RMSE : 183.75078715749436
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 8ms/step - loss: 0.0450
# RMSE : 159.6650230815729
# {'epochs': 50, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 6s 8ms/step - loss: 0.0477
# RMSE : 206.28962489883463
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 8ms/step - loss: 0.0328
# RMSE : 153.2643177627553
# {'epochs': 100, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 6s 8ms/step - loss: 0.0682
# RMSE : 205.91082319406686
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 7s 8ms/step - loss: 0.0489
# RMSE : 195.09486469484193
# {'epochs': 30, 'npartitions': 100, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 7s 8ms/step - loss: 0.0306
# RMSE : 169.2045793972844
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 8ms/step - loss: 0.0305
# RMSE : 156.1788558557487
# {'epochs': 50, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 8ms/step - loss: 0.0481
# RMSE : 175.61782889124768
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 7s 8ms/step - loss: 0.0368
# RMSE : 174.54262557510364
# {'epochs': 100, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 8ms/step - loss: 0.0766
# RMSE : 165.28297049613704
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 7s 8ms/step - loss: 0.0352
# RMSE : 166.39886648325347
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0456
# RMSE : 175.89466719519828
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0348
# RMSE : 159.33379260591286
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0383
# RMSE : 151.6168118298063
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0333
# RMSE : 165.95627819885715
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0346
# RMSE : 158.10439864128946
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0334
# RMSE : 153.7880259959128
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 7s 9ms/step - loss: 0.0352
# RMSE : 161.14785932766242
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0398
# RMSE : 154.0501475950562
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0362
# RMSE : 154.46114496774655
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0421
# RMSE : 158.46084463999438
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0328
# RMSE : 159.09060383640306
# {'epochs': 30, 'npartitions': 200, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 8s 9ms/step - loss: 0.0365
# RMSE : 174.73315812253787
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0416
# RMSE : 160.57813120565277
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 8s 9ms/step - loss: 0.0360
# RMSE : 182.92632772093629
# {'epochs': 30, 'npartitions': 200, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 8s 10ms/step - loss: 0.0430
# RMSE : 187.812612389849
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0382
# RMSE : 162.12767762394273
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0372
# RMSE : 162.80911985563904
# {'epochs': 50, 'npartitions': 150, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 8s 10ms/step - loss: 0.0461
# RMSE : 190.27587334346626
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0357
# RMSE : 154.9036948208878
# {'epochs': 100, 'npartitions': 200, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 8s 10ms/step - loss: 0.0748
# RMSE : 213.27206358575805
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0369
# RMSE : 152.64920120754135
# {'epochs': 30, 'npartitions': 100, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 8s 9ms/step - loss: 0.0443
# RMSE : 172.88744839701403
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 8s 9ms/step - loss: 0.0452
# RMSE : 201.08361657164266
# {'epochs': 50, 'npartitions': 200, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 9s 10ms/step - loss: 0.0508
# RMSE : 211.83298739490135
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0386
# RMSE : 155.69108004376798
# {'epochs': 100, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 10ms/step - loss: 0.0743
# RMSE : 171.771160515361
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 8s 10ms/step - loss: 0.0427
# RMSE : 176.58329697182745
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 9ms/step - loss: 0.0352
# RMSE : 160.7831004901428
# {'epochs': 30, 'npartitions': 100, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 9s 10ms/step - loss: 0.0330
# RMSE : 180.8966783592217
# {'epochs': 30, 'npartitions': 200, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 10ms/step - loss: 0.0375
# RMSE : 157.96340025930485
# {'epochs': 50, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 8s 10ms/step - loss: 0.0580
# RMSE : 203.21720496758365
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 10ms/step - loss: 0.0376
# RMSE : 148.20706450459735
# {'epochs': 100, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 8s 10ms/step - loss: 0.0940
# RMSE : 279.5407451762107
# {'epochs': 30, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 9s 10ms/step - loss: 0.0406
# RMSE : 193.3338772286096
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 10ms/step - loss: 0.0357
# RMSE : 156.03573892447199
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 10ms/step - loss: 0.0349
# RMSE : 152.13706421570424
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 9s 10ms/step - loss: 0.0392
# RMSE : 175.43293108908944
# {'epochs': 50, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 10ms/step - loss: 0.0481
# RMSE : 190.54742894327927
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 9s 10ms/step - loss: 0.0320
# RMSE : 167.30194672791885
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 8s 10ms/step - loss: 0.0811
# RMSE : 234.70077509847798
# {'epochs': 30, 'npartitions': 50, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 9s 10ms/step - loss: 0.0423
# RMSE : 183.54237674334703
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 10ms/step - loss: 0.0380
# RMSE : 151.00164871415043
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 10ms/step - loss: 0.0390
# RMSE : 162.80467506462773
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 9s 10ms/step - loss: 0.0410
# RMSE : 192.94538664466086
# {'epochs': 50, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 9s 11ms/step - loss: 0.0414
# RMSE : 195.93707069885883
# {'epochs': 30, 'npartitions': 150, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 11ms/step - loss: 0.0388
# RMSE : 152.11227014377454
# {'epochs': 100, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 10ms/step - loss: 0.0956
# RMSE : 254.79420174739042
# {'epochs': 30, 'npartitions': 50, 'order': 6}
# Epoch 1/1
# 848/848 [==============================] - 9s 11ms/step - loss: 0.0352
# RMSE : 170.78998076797512
# {'epochs': 30, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 11ms/step - loss: 0.0426
# RMSE : 154.0859666632146
# {'epochs': 30, 'npartitions': 100, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 11ms/step - loss: 0.0381
# RMSE : 160.0756591265308
# {'epochs': 30, 'npartitions': 50, 'order': 8}
# Epoch 1/1
# 846/846 [==============================] - 9s 11ms/step - loss: 0.0360
# RMSE : 179.61862352242272
# {'epochs': 50, 'npartitions': 50, 'order': 4}
# Epoch 1/1
# 850/850 [==============================] - 9s 11ms/step - loss: 0.0699
# RMSE : 168.66252730335916
# {'epochs': 30, 'npartitions': 150, 'order': 5}
# Epoch 1/1
# 849/849 [==============================] - 10s 11ms/step - loss: 0.0378
# RMSE : 162.87468939418147
# {'epochs': 30, 'npartitions': 50, 'order': 7}
# Epoch 1/1
# 847/847 [==============================] - 10s 11ms/step - loss: 0.0372
# RMSE : 193.93424237405887
# {'epochs': 100, 'npartitions': 50, 'order': 9}
# Epoch 1/1
# 845/845 [==============================] - 9s 11ms/step - loss: 0.0727
# RMSE : 210.81252948476572

# %%
print('best: ')
print(space_eval(space, best))
# Out:
# best:
# {'epochs': 30, 'npartitions': 50, 'order': 4}

# %% [markdown]
# ## Persistence

# %%
def persistence_forecast(train, test, step):
    predictions = []
    
    for t in np.arange(0,len(test), step):
        yhat = [test.iloc[t]]  * step
        predictions.extend(yhat)
        
    return predictions

# %%
step = 1
persistence_order = 1

forecast = persistence_forecast(norm_train_df[target_station], norm_test_df[target_station],step)
forecast = denormalize(forecast, min_raw, max_raw)

rmse = calculate_rmse(test_df[target_station], forecast, persistence_order, step)
# Out:
# RMSE : 126.5116260261361

# %%
result = {'rmse': rmse, 'final': forecast}
save_obj(result, name="oahu_raw_persistence_1")

# %% [markdown]
# ## Long Short Term Memory - LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def lstm_multi_forecast(train_df, test_df, _order, _steps, _neurons, _epochs):

    
    nfeat = len(train_df.columns)
    nlags = _order
    nsteps = _steps
    nobs = nlags * nfeat
    
    train_reshaped_df = series_to_supervised(train_df, n_in=nlags, n_out=nsteps)
    train_X, train_Y = train_reshaped_df.iloc[:,:nobs].values, train_reshaped_df.iloc[:,-nfeat].values
    train_X = train_X.reshape((train_X.shape[0], nlags, nfeat))
    
    test_reshaped_df = series_to_supervised(test_df, n_in=nlags, n_out=nsteps)
    test_X, test_Y = test_reshaped_df.iloc[:,:nobs].values, test_reshaped_df.iloc[:,-nfeat].values
    test_X = test_X.reshape((test_X.shape[0], nlags, nfeat))
    
    # design network
    model = Sequential()
    model.add(LSTM(_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')
    
    # fit network
    model.fit(train_X, train_Y, epochs=_epochs, batch_size=72, verbose=False, shuffle=False)
    
    forecast = model.predict(test_X)
        
    return forecast

# %%
neurons = 50
lstm_order = 2
epochs = 100
steps = 1

forecast = lstm_multi_forecast(norm_train_df[[target_station]], norm_test_df[[target_station]], lstm_order, steps, neurons, epochs)
forecast = denormalize(forecast, min_raw, max_raw)

# %%
forecast.append(0) ## para manter o mesmo tamanho dos demais

# %%
rmse = calculate_rmse(test_df[target_station], forecast, lstm_order, steps)
# Out:
# RMSE : 123.35325991355555

# %%
result = {'rmse': rmse, 'final': forecast}
save_obj(result, name="oahu_raw_lstm_multi_1")

# %% [markdown]
# ## Multi Layer Perceptron - MLP

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def mlp_forecast(train_df, test_df, _order, _steps, _neurons, _epochs):

    
    nfeat = len(train_df.columns)
    nlags = _order
    nsteps = _steps
    nobs = nlags * nfeat
    
    train_reshaped_df = series_to_supervised(train_df, n_in=nlags, n_out=nsteps)
    train_X, train_Y = train_reshaped_df.iloc[:,:nobs].values, train_reshaped_df.iloc[:,-nfeat].values
    
    test_reshaped_df = series_to_supervised(test_df, n_in=nlags, n_out=nsteps)
    test_X, test_Y = test_reshaped_df.iloc[:,:nobs].values, test_reshaped_df.iloc[:,-nfeat].values
    
    # design network
    model = Sequential()
    model.add(Dense(neurons, activation='relu', input_dim=train_X.shape[1]))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')

    # fit network
    history = model.fit(train_X, train_Y, epochs=_epochs, batch_size=72, verbose=False, shuffle=False)   

    forecast = model.predict(test_X)
        
    return forecast

# %%
neurons = 50
mlp_order = 4
epochs = 500
steps = 1

forecast = mlp_forecast(norm_train_df[[target_station]], norm_test_df[[target_station]], mlp_order, steps, neurons, epochs)
forecast = denormalize(forecast, min_raw, max_raw)

forecast.append(0) ## para manter o mesmo tamanho dos demais

rmse = calculate_rmse(test_df[target_station], forecast, mlp_order, steps)

# %%
result = {'rmse': rmse, 'final': forecast}
save_obj(result, name="oahu_raw_mlp_uni_1")
